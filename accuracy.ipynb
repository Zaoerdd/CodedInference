# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['nf=0', 'nf=1', 'nf=2']

# 方案1: E: Conv, D: MLP
acc_conv_mlp_full = [80.22, 73.16, 61.29]
# acc_conv_mlp_partial = [81.77, 74.69, 63.98]

# 方案2: E: Conv, D: SparseMLP 
acc_conv_sparse_full = [82.19, 78.56, 69.97]
# acc_conv_sparse_partial = [85.47, 82.79, 72.88]

# 方案3: E/D: SparseMLP (Full Split)
acc_sparse_full = [83.08, 79.11, 71.45]

# 方案4: E/D: SparseMLP (Partial Split)
# acc_sparse_partial = [85.98, 82.86, 74.13]


x = np.arange(len(categories))
total_width = 0.8 
n_bars = 6  
width = total_width / n_bars

fig, ax = plt.subplots(figsize=(6, 6))

rects1 = ax.bar(x - 2.5 * width, acc_conv_mlp_full, width, label='Conv+MLP (Full Split)', color='#4477CC', edgecolor='black')
# rects2 = ax.bar(x - 1.5 * width, acc_conv_mlp_partial, width, label='Conv+MLP (Partial Split)', color='#5599FF', edgecolor='black')
rects3 = ax.bar(x - 0.5 * width, acc_conv_sparse_full, width, label='Conv+SparseMLP (Full Split)', color='#77CC33', edgecolor='black')
# rects4 = ax.bar(x + 0.5 * width, acc_conv_sparse_partial, width, label='Conv+SparseMLP (Partial Split)', color='#99DD55', edgecolor='black')
rects5 = ax.bar(x + 1.5 * width, acc_sparse_full, width, label='SparseMLP (Full Split)', color='#AA4499', edgecolor='black')
# rects6 = ax.bar(x + 2.5 * width, acc_sparse_partial, width, label='SparseMLP (Partial Split)', color='#FF6666', edgecolor='black')

ax.set_ylabel('Accuracy (%)', fontsize=12, fontweight='bold')
ax.set_xlabel('Number of Stragglers/Losses', fontsize=12, fontweight='bold')
ax.set_title('Robustness Comparison on CIFAR10 (K=4, R=2)', fontsize=14, pad=20)
ax.set_xticks(x)
ax.set_xticklabels(categories, fontsize=11)
ax.set_ylim(50, 100)  # 设置Y轴范围
ax.legend(fontsize=10, loc='upper right')
ax.grid(axis='y', linestyle='--', alpha=0.5)

def autolabel(rects):
    """在每个柱子上方显示数值"""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 垂直偏移
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=9, fontweight='bold')

autolabel(rects1)
# autolabel(rects2)
autolabel(rects3)
# autolabel(rects4) 
autolabel(rects5)
# autolabel(rects6)
plt.tight_layout()
# plt.savefig('adjusted_accuracy_chart.png', dpi=300) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['nf=0', 'nf=1', 'nf=2']

# 方案1: E: Conv, D: MLP
acc_conv_mlp_full = [80.22, 73.16, 61.29]
# acc_conv_mlp_partial = [81.77, 74.69, 63.98]

# 方案2: E: Conv, D: SparseMLP 
acc_conv_sparse_full = [82.19, 78.56, 69.97]
# acc_conv_sparse_partial = [85.47, 82.79, 72.88]

# 方案3: E/D: SparseMLP (Full Split)
acc_sparse_full = [83.08, 79.11, 71.45]

# 方案4: E/D: SparseMLP (Partial Split)
# acc_sparse_partial = [85.98, 82.86, 74.13]


x = np.arange(len(categories))
total_width = 0.8 
n_bars = 3  
width = total_width / n_bars

fig, ax = plt.subplots(figsize=(6, 6))

rects1 = ax.bar(x - 1 * width, acc_conv_mlp_full, width,  color='#4477CC', edgecolor='black')
# rects2 = ax.bar(x - 1.5 * width, acc_conv_mlp_partial, width, label='Conv+MLP (Partial Split)', color='#5599FF', edgecolor='black')
rects3 = ax.bar(x, acc_conv_sparse_full, width,  color='#77CC33', edgecolor='black')
# rects4 = ax.bar(x + 0.5 * width, acc_conv_sparse_partial, width, label='Conv+SparseMLP (Partial Split)', color='#99DD55', edgecolor='black')
rects5 = ax.bar(x + 1 * width, acc_sparse_full, width,  color='#AA4499', edgecolor='black')
# rects6 = ax.bar(x + 2.5 * width, acc_sparse_partial, width, label='SparseMLP (Partial Split)', color='#FF6666', edgecolor='black')

ax.set_ylabel('Accuracy (%)', fontsize=15)
# ax.set_xlabel('Number of Stragglers/Losses', fontsize=12, fontweight='bold')
# ax.set_title('Robustness Comparison on CIFAR10 (K=4, R=2)', fontsize=14, pad=20)
ax.set_xticks(x)
ax.set_xticklabels(categories, fontsize=11)
ax.set_ylim(50, 100)  # 设置Y轴范围
ax.legend(fontsize=10, loc='upper right')
ax.grid(axis='y', linestyle='--', alpha=0.5)

def autolabel(rects):
    """在每个柱子上方显示数值"""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 垂直偏移
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=9, fontweight='bold')

autolabel(rects1)
# autolabel(rects2)
autolabel(rects3)
# autolabel(rects4) 
autolabel(rects5)
# autolabel(rects6)
plt.tight_layout()
plt.savefig('accuracy_CIFAR10.pdf', dpi=300) 
plt.show()
# Out:
# C:\Users\Zaoer\AppData\Local\Temp\ipykernel_41464\1245432546.py:41: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=10, loc='upper right')

# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['nf=0', 'nf=1', 'nf=2']

# 方案1: E: Conv, D: MLP
acc_conv_mlp_full = [78.09, 70.07, 58.44]
# acc_conv_mlp_partial = [81.77, 74.69, 63.98]

# 方案2: E: Conv, D: SparseMLP 
acc_conv_sparse_full = [80.71, 77.23, 71.86]
# acc_conv_sparse_partial = [85.47, 82.79, 72.88]

# 方案3: E/D: SparseMLP (Full Split)
acc_sparse_full = [81.23, 79.46, 72.01]

# 方案4: E/D: SparseMLP (Partial Split)
# acc_sparse_partial = [85.98, 82.86, 74.13]


x = np.arange(len(categories))
total_width = 0.8 
n_bars = 3  
width = total_width / n_bars

fig, ax = plt.subplots(figsize=(6, 6))

rects1 = ax.bar(x - 1 * width, acc_conv_mlp_full, width, label='Conv+MLP', color='#4477CC', edgecolor='black')
# rects2 = ax.bar(x - 1.5 * width, acc_conv_mlp_partial, width, label='Conv+MLP (Partial Split)', color='#5599FF', edgecolor='black')
rects3 = ax.bar(x, acc_conv_sparse_full, width, label='Conv+SparseMLP', color='#77CC33', edgecolor='black')
# rects4 = ax.bar(x + 0.5 * width, acc_conv_sparse_partial, width, label='Conv+SparseMLP (Partial Split)', color='#99DD55', edgecolor='black')
rects5 = ax.bar(x + 1 * width, acc_sparse_full, width, label='SparseMLP', color='#AA4499', edgecolor='black')
# rects6 = ax.bar(x + 2.5 * width, acc_sparse_partial, width, label='SparseMLP (Partial Split)', color='#FF6666', edgecolor='black')

ax.set_ylabel('Accuracy (%)', fontsize=15)
# ax.set_xlabel('Number of Stragglers/Losses', fontsize=12, fontweight='bold')
# ax.set_title('Robustness Comparison on Imagenet10 (K=4, R=2)', fontsize=14, pad=20)
ax.set_xticks(x)
ax.set_xticklabels(categories, fontsize=11)
ax.set_ylim(50, 100)  # 设置Y轴范围
ax.legend(fontsize=10, loc='upper right')
ax.grid(axis='y', linestyle='--', alpha=0.5)

def autolabel(rects):
    """在每个柱子上方显示数值"""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 垂直偏移
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=9, fontweight='bold')

autolabel(rects1)
# autolabel(rects2)
autolabel(rects3)
# autolabel(rects4) 
autolabel(rects5)
# autolabel(rects6)
plt.tight_layout()
plt.savefig('accuracy_Imagenet10.pdf', dpi=300) 
plt.show()
