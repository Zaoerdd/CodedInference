# %% [markdown]
# Test for the network straggling effect of Scenario (iii)

# %% [markdown]
# ### Set packet loss on sending from master

# %%
# PC as the master, wired connection
# n=10 r=20
# Mean=1.4939814603328705, Var=0.04718210792761015
# n=10 r=50
# Mean=1.4113136205673218, Var=0.09930400142567529
# Mean=1.4794289283752442, Var=0.05638155372606209

# n=10 r=50
# Mean=1.4923072028160096, Var=0.10876841980568548
# Means=[1.346799   1.64265528 1.36348053 1.50298482 1.1136095  1.46410764
#  1.44734808 1.72485799 1.62147579 1.6957534 ]
# Vars=[0.04825295 0.07319146 0.02549141 0.02896682 0.02443835 0.07853315
#  0.22027987 0.12907497 0.13526095 0.00532352]

# Pi as the master
# wireless connection
# n=10 r=50
# Mean=2.0078001537323, Var=1.095146856041146
# Mean=1.8298610954284669, Var=0.8039215000470642
# Mean=2.2095133690834046, Var=1.2285781158154656

# wired connection
# n=10 r=50
# loss 0%
# Mean=1.1862039141654968, Var=0.21014576619192518
# Means=[0.70389493 0.74566818 0.94596695 0.83707294 1.15744961 1.09833314
#  1.33400808 1.6871479  1.60858453 1.74391288]
# Vars=[0.25466945 0.16784565 0.08747616 0.06796534 0.02555882 0.02794698
#  0.03406042 0.0129282  0.03006802 0.01585499]


# loss 1% 30%
# Mean=1.229328456401825, Var=0.2880943404031506
# Means=[0.37952841 0.56647905 0.94808355 1.1027282  1.22411659 1.34466305
#  1.48985888 1.53099626 1.82555411 1.88127648]
# Vars=[0.03152947 0.09223627 0.09386474 0.10747362 0.06539184 0.03368552
#  0.09953245 0.05418978 0.03260714 0.06104674]


# loss 1%
# Mean=2.0595691146850585, Var=1.1633927343477921
# Means=[0.42009647 0.81823929 1.15815795 1.47045379 1.82242589 2.19643425
#  2.90945483 2.92669216 3.27374004 3.59999649]
# Vars=[0.00506827 0.03741365 0.03286299 0.04104547 0.06821633 0.08435672
#  0.15377276 0.12455031 0.14813212 0.15383491]

# loss 2%
# Mean=3.0249428334236144, Var=2.519303915465499
# Means=[0.61346647 1.07889103 1.59611191 2.04140832 2.96221021 3.44101652
#  3.96877188 4.34759372 4.85052665 5.34943161]
# Vars=[0.02062728 0.04828601 0.06046899 0.05589283 0.09970241 0.14001609
#  0.14810437 0.12685102 0.16074491 0.1678358 ]

# loss 3%
# Mean=4.168727951049805, Var=4.843911002712888
# Means=[0.83367539 1.53536456 2.25131388 2.90612604 3.6003297  4.87790279
#  5.52061738 6.22059226 6.69987468 7.24148284]
# Vars=[0.04251978 0.06400672 0.08214878 0.14010072 0.18832059 0.30127933
#  0.32154456 0.41501143 0.39713173 0.44694365]

# loss 4%
# Mean=5.208825775623321, Var=6.818138035614773
# Means=[1.03195897 2.37184462 2.96133611 3.85877956 4.71749121 5.67963
#  6.51722508 7.38259895 8.34507791 9.22231534]
# Vars=[0.08409938 0.20947828 0.16027258 0.18026959 0.25367478 0.40346548
#  0.35555496 0.39448788 0.46610512 0.46101849]

# loss 1% 30%

# %% [markdown]
# Inference Latency

# %% [markdown]
# Loss=0%

# %%
# repetition and uncoded

# test1-=day=20240619--r=10
# 'repetition': {'min':16.870529890060425, 'mean':17.565940380096436, 'max':18.56821584701538}
# 'uncoded': {'min':11.320072889328003, 'mean':11.76582336425781, 'max':13.11426854133606}
# 'coded-4': {'min':14.317496299743652, 'mean':15.1770405292511, 'max':16.592817544937134}
# 'coded-3': {'min':13.45791220664978, 'mean':14.167340922355649, 'max':14.97966194152832}
# 'coded-2': {'min':13.064213752746582, 'mean':13.389368557929993, 'max':13.87044095993042}
# 'coded-1': {'min':12.41334080696106, 'mean':12.758149003982545, 'max':13.295486450195312}
#   'coded': {'mean':12.44713878631592}

# %% [markdown]
# Loss=1%

# %%
# test1-=day=20240619--r=10
# 'repetition': {'min':18.52277374267578, 'mean':20.0539621591568, 'max':21.562081336975098}
# 'uncoded': {'min':12.930570363998413, 'mean':13.763979625701905, 'max':16.20702075958252}
# 'coded-4': {'min':16.17165732383728, 'mean':17.863977980613708, 'max':19.43397545814514}
# 'coded-3': {'min':14.949097394943237, 'mean':15.750303745269774, 'max':16.885998249053955}
# 'coded-2': {'min':14.508139371871948, 'mean':15.485539388656616, 'max':16.325597763061523}
# 'coded-1': {'min':13.857811450958252, 'mean':14.763703417778018, 'max':15.754207134246826}
#   'coded': {'mean':14.395465159416197}

# %% [markdown]
# Loss=2%

# %%
# test1-=day=20240620--r=10
# 'repetition': {'min':20.647411108016968, 'mean':22.453694128990175, 'max':25.5735867023468}
# 'uncoded': {'min':14.823324203491211, 'mean':16.04542336463928, 'max':18.36434030532837}
# 'coded-4': {'min':19.012784242630005, 'mean':20.201300859451294, 'max':21.420409440994263}
# 'coded-3': {'min':17.696789264678955, 'mean':18.854252672195432, 'max':20.4285249710083}
# 'coded-2': {'min':16.4319908618927, 'mean':18.10876867771149, 'max':19.887118816375732}
# 'coded-1': {'min':15.192256212234497, 'mean':16.415131831169127, 'max':18.598637580871582}
#   'coded': {'mean':16.115149950981138}

# %% [markdown]
# Loss=3%

# %%
# test1-=day=20240620--r=10
# 'repetition': {'min':25.731475114822388, 'mean':28.976322722434997, 'max':31.73574209213257}
# 'uncoded': {'min':18.30642795562744, 'mean':21.586071181297303, 'max':26.373243808746338}

# 'coded-4': {'min':21.623784065246582, 'mean':23.89968876838684, 'max':26.530746698379517}
# 'coded-3': {'min':20.058399200439453, 'mean':21.674846458435052, 'max':23.40690517425537}
# 'coded-2': {'min':19.322684288024902, 'mean':20.73380897045136, 'max':22.310367584228516}
# 'coded-1': {'min':19.611740350723267, 'mean':20.933458161354068, 'max':23.11548948287964}
#   'coded': {20.344063735008245}

# %% [markdown]
# Loss=4%

# %%
# test1-=day=20240620--r=10
# 'repetition': {'min':28.413456678390503, 'mean':30.471356248855592, 'max':33.300026655197144}
# 'uncoded': {'min':20.178917407989502, 'mean':22.50897176265716, 'max':26.07988405227661}

# 'repetition': {'min':29.625452518463135, 'mean':31.830609917640686, 'max':35.27179837226868}
# 'uncoded': {'min':20.636536836624146, 'mean':23.374377751350405, 'max':28.83451223373413}



# 'coded-4': {'min':25.892693996429443, 'mean':29.177289700508116, 'max':31.571901082992554}
# 'coded-3': {'min':22.510238647460938, 'mean':25.93330154418945, 'max':29.873462915420532}
# 'coded-2': {'min':22.14396023750305, 'mean':24.234484720230103, 'max':27.486955404281616}
# 'coded-1': {'min':21.47224450111389, 'mean':23.58602654933929, 'max':26.652957916259766}
#   'coded': {22.992366838455197}

# 'coded-4': {'min':25.927930116653442, 'mean':28.746282529830932, 'max':31.31660270690918}
# 'coded-3': {'min':23.23802089691162, 'mean':25.812753367424012, 'max':29.159257650375366}
# 'coded-2': {'min':21.84414005279541, 'mean':24.091981840133663, 'max':27.794456720352173}
# 'coded-1': {'min':21.337515115737915, 'mean':23.551804399490358, 'max':27.33968210220337}
#   'coded': {23.067691445350643}

# %% [markdown]
# ### Plot Data
# Line chart with mean latency of the corresponding method as the y-axis and the packet loss rate (reflecting the straggling effect) as the x-axis

# %%
import numpy as np
import matplotlib.pyplot as plt

# local
vgg16_local = 50.09890913963318

loss = [str(i) for i in range(5)]


# 'repetition': {'min':25.731475114822388, 'mean':28.976322722434997, 'max':31.73574209213257}
# 'uncoded': {'min':18.30642795562744, 'mean':21.586071181297303, 'max':26.373243808746338}

# 'coded-4': {'min':21.623784065246582, 'mean':23.89968876838684, 'max':26.530746698379517}
# 'coded-3': {'min':20.058399200439453, 'mean':21.674846458435052, 'max':23.40690517425537}
# 'coded-2': {'min':19.322684288024902, 'mean':20.73380897045136, 'max':22.310367584228516}
# 'coded-1': {'min':19.611740350723267, 'mean':20.933458161354068, 'max':23.11548948287964}
#   'coded': {20.344063735008245}

# repetition latency
repetition_latency = [17.565940380096436, 20.0539621591568, 22.453694128990175, 28.976322722434997, 31.830609917640686]
# uncoded latency
uncoded_latency = [11.76582336425781, 13.763979625701905, 16.04542336463928, 21.586071181297303, 23.374377751350405]
# coded latency
coded_latency = [12.758149003982545, 14.395465159416197, 16.115149950981138, 20.344063735008245, 22.992366838455197]

# %%
plt.grid(axis='y')

plt.plot(loss, )
plt.plot(loss, repetition_latency, '^--', label='repetition')
plt.plot(loss, uncoded_latency, 'o--', label='uncoded')
plt.plot(loss, coded_latency, '*--', label='coded')
plt.xlabel('Loss rate(%)')
plt.ylabel('Mean of $T^c$')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Set packet loss on sending from workers

# %%
# loss=0%
# 'repetition': {'min':17.586503744125366, 'mean':18.42767291069031, 'max':19.361836433410645}
# 'uncoded': {'min':10.00096344947815, 'mean':10.151431512832641, 'max':10.3780996799469}
# 'coded-4': {'min':14.506386041641235, 'mean':14.846416330337526, 'max':15.28488302230835}
# 'coded-3': {'min':13.722830057144165, 'mean':14.057733488082885, 'max':14.470637798309326}
# 'coded-2': {'min':12.359263896942139, 'mean':12.625100803375242, 'max':12.89395809173584}
# 'coded-1': {'min':11.463963985443115, 'mean':11.645413637161255, 'max':11.86476182937622}

# loss=1%
# 'repetition': {'min':17.366516828536987, 'mean':18.676343488693238, 'max':20.27528977394104}
# 'uncoded': {'min':10.425057649612427, 'mean':10.829320240020753, 'max':11.394939661026001}
# 'coded-4': {'min':15.09364128112793, 'mean':15.695168972015383, 'max':16.298290014266968}
# 'coded-3': {'min':14.0484037399292, 'mean':14.587236928939818, 'max':15.050362825393677}
# 'coded-2': {'min':12.389994859695435, 'mean':12.693744945526126, 'max':13.016749143600464}
# 'coded-1': {'min':11.535202741622925, 'mean':11.860500884056094, 'max':12.222495317459106}

# loss=2%
# 'repetition': {'min':18.210420846939087, 'mean':19.397320365905763, 'max':20.302167415618896}
# 'uncoded': {'min':10.682398796081543, 'mean':11.235529470443726, 'max':12.068034887313843}
# 'coded-4': {'min':15.22000527381897, 'mean':15.992429447174072, 'max':16.809870958328247}
# 'coded-3': {'min':14.572111368179321, 'mean':14.983697605133058, 'max':15.458924293518066}
# 'coded-2': {'min':12.655716180801392, 'mean':13.26129298210144, 'max':13.83368468284607}
# 'coded-1': {'min':12.023857355117798, 'mean':12.419846534729006, 'max':12.848995685577393}

# loss=5%
# 'repetition': {'min':23.574419021606445, 'mean':24.842671823501583, 'max':26.165279626846313}
# 'uncoded': {'min':13.867920637130737, 'mean':15.533112001419067, 'max':17.348860502243042}
# 'coded-5': {'min':23.161303281784058, 'mean':24.504451036453244, 'max':25.508485078811646}
# 'coded-4': {'min':19.28503394126892, 'mean':20.589331340789794, 'max':21.688294649124146}
# 'coded-3': {'min':18.386234760284424, 'mean':19.602420330047607, 'max':20.885050773620605}
# 'coded-2': {'min':16.149023294448853, 'mean':17.36397805213928, 'max':19.014309644699097}
# 'coded-1': {'min':15.10309910774231, 'mean':16.061885690689085, 'max':16.984437942504883}

# loss=8%
# 'repetition': {'min':28.04049563407898, 'mean':29.687207555770872, 'max':31.72143793106079}
# 'uncoded': {'min':18.814118146896362, 'mean':22.10016446113586, 'max':26.465976238250732}
# 'coded-5': {'min':27.994534015655518, 'mean':29.114988231658934, 'max':30.528789520263672}
# 'coded-4': {'min':24.743422508239746, 'mean':25.83806629180908, 'max':26.743552207946777}
# 'coded-3': {'min':24.476916074752808, 'mean':25.31602101325989, 'max':26.330246925354004}
# 'coded-2': {'min':21.089058876037598, 'mean':23.451889085769658, 'max':25.353981733322144}
# 'coded-1': {'min':19.997008323669434, 'mean':22.158901071548463, 'max':24.32928442955017}
